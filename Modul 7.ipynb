# %% [markdown]
# <a href="https://colab.research.google.com/github/chelscys/praktikum-algo-pak-anung/blob/main/Modul%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Chelscy Maria Margaretha
# 065002500018

def cek_prima(x):
    if x <= 1:
        return False
    if x == 2:
        return True
    for i in range(2, x):
        if x % i == 0:
            return False
    return True

def tampil_hasil_prima(angka, status_prima):
    if status_prima:
        print(f"{angka} adalah bilangan Prima")
    else:
        print(f"{angka} bukanlah bilangan Prima")

angka_input = int(input("Masukkan angka: "))
status = cek_prima(angka_input)
tampil_hasil_prima(angka_input, status)
# Out:
# Masukkan angka: 102
# 102 bukanlah bilangan Prima

# %%
# Chelscy Maria Margaretha
# 065002500018

def dapatkan_akhiran_ordinal(n):
    if n == 0:
        return 'th'

    dua_digit_terakhir = n % 100
    if 10 <= dua_digit_terakhir <= 20:
        return 'th'

    digit_terakhir = n % 10
    if digit_terakhir == 1:
        akhiran = 'st'
    elif digit_terakhir == 2:
        akhiran = 'nd'
    elif digit_terakhir == 3:
        akhiran = 'rd'
    else:
        akhiran = 'th'
    return akhiran

print("Ordinal Number")
print("ketik 0 untuk menghentikan program")

while True:
    angka = int(input("masukkan angka: "))
    suffix = dapatkan_akhiran_ordinal(angka)
    print(f"({angka}, '{suffix}')")

    if angka == 0:
        print("terima kasih telah menggunakan program saya")
        break
# Out:
# Ordinal Number
# ketik 0 untuk menghentikan program
# masukkan angka: 1
# (1, 'st')
# masukkan angka: 2
# (2, 'nd')
# masukkan angka: 3
# (3, 'rd')
# masukkan angka: 0
# (0, 'th')
# terima kasih telah menggunakan program saya
